# %%
# make a prediction with a multinomial logistic regression model
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
import pandas as pd
df = pd.read_csv('persons_csv.csv')
df = df.head(50)
df.loc[df['gender'] == 'Male', 'gender'] = 1 # Change from string to numeric value
df.loc[df['gender'] == 'Female', 'gender'] = 0
X = df.drop(['size_value', 'size', 'gender'], axis=1).copy()  # New df without size or size value column
X = X.to_numpy()
y = df.size_value.copy().to_numpy()
y = y.astype('int32')

# %%
# evaluate multinomial logistic regression model
from numpy import mean
from numpy import std
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.linear_model import LogisticRegression


# define the multinomial logistic regression model
model = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=10)
model.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/PycharmProjects/BigData/size_generator/venv/lib/python3.10/site-packages/numpy/core/getlimits.py:649, in iinfo.__init__(self, int_type)
#     648 try:
# --> 649     self.dtype = numeric.dtype(int_type)
#     650 except TypeError:
#
# TypeError: 'NoneType' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [81], in <cell line: 11>()
#       9 # define the multinomial logistic regression model
#      10 model = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=10)
# ---> 11 model.fit(X,y)
#
# File ~/PycharmProjects/BigData/size_generator/venv/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1589, in LogisticRegression.fit(self, X, y, sample_weight)
# ...

# %%
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, n_classes=3, random_state=1)
# define the multinomial logistic regression model
model = LogisticRegression(multi_class='multinomial', solver='lbfgs')
# fit the model on the whole dataset
model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [44], in <cell line: 3>()
#       1 X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, n_classes=3, random_state=1)
#       2 # define the multinomial logistic regression model
# ----> 3 model = LogisticRegression(multi_class='multinomial', solver='lbfgs')
#       4 # fit the model on the whole dataset
#       5 model.fit(X, y)
#
# Input In [44], in <cell line: 3>()
#       1 X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, n_classes=3, random_state=1)
#       2 # define the multinomial logistic regression model
# ----> 3 model = LogisticRegression(multi_class='multinomial', solver='lbfgs')
#       4 # fit the model on the whole dataset
#       5 model.fit(X, y)
#
# ...
